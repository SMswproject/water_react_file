# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas

# %%
path = "/content/drive/MyDrive/dmz_teamproject/dataset/detection_data.v4i.yolov5pytorch/train/rotate_grayscale_labels/"

for file in os.listdir(path):

    new_name = path + "grayscale__" + file
    
    os.rename(path + file , new_name)

# %%
for file in os.listdir(path):

    print(file)
# Out:
# grayscale__grayscale__rotate__img_0275_jpeg.rf.3b96cfdfd365a3d26131d5f786ec8e5c.txt
# grayscale__grayscale__rotate__img_0330_jpeg.rf.2d771f1366f0af8c1a01ae3e08089c0e.txt
# grayscale__grayscale__rotate__img_0218_jpeg.rf.90dd650d4606b37a30ba95e9899dc4d8.txt
# grayscale__grayscale__rotate__img_0263_jpeg.rf.4cf22bc00e89bb5ce757f9eeb9d4551d.txt
# grayscale__grayscale__rotate__img_0189_jpeg.rf.c94910cd52563acf7a5ab811f5989b35.txt
# grayscale__grayscale__rotate__img_0263_jpeg.rf.f541b42d42679056b0075fd8b1497a51.txt
# grayscale__grayscale__rotate__img_0218_jpeg.rf.a9cd2bb44cac4395956e936258f3eba6.txt
# grayscale__grayscale__rotate__img_0189_jpeg.rf.f6129ac51fe411267415d09869786b1e.txt
# grayscale__grayscale__rotate__img_0189_jpeg.rf.230ce374f9f85a5bfb6da2af9b9cc077.txt
# grayscale__grayscale__rotate__img_0218_jpeg.rf.a304385d39c6ce0ca53f49069e4395c7.txt
# grayscale__grayscale__rotate__img_0062_jpeg.rf.8b49cf864f5f1fe0288a4f46ec625622.txt
# ...
